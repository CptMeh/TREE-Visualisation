# %%
import pandas as pd
import numpy as np

df = pd.read_csv("./TREE2_Data_IWI_Open_Data_Vorlesung_2023_nolabel.csv")

df = df[df['t1bqvalids'] != 'No valid response']
df = df[df['t2bqvalids'] != 'No valid response']
df = df[df['t3bqvalids'] != 'No valid response']



df = df.dropna()
df
# Out:
#       resp_id  aes_canton  aes_langreg  t0sex  t0fmedu_comp  t0immig
# 1     1011011          10            2      1           1.0      3.0  \
# 3     1011013          11            1      1           1.0      1.0
# 6     1011020          15            1      1           1.0      1.0
# 7     1011021          10            1      1           1.0      1.0
# 8     1011027          10            1      2           1.0      1.0
# ...       ...         ...          ...    ...           ...      ...
# 8420  9013468          22            2      2           0.0      1.0
# 8422  9013470          13            1      1           1.0      1.0
# 8424  9013473          11            1      1           2.0      1.0
# 8425  9013481          11            1      2           1.0      1.0
# 8427  9013497          21            3      1           2.0      1.0
#
#       t1bqvalids t2bqvalids t3bqvalids       t1wt       t2wt       t3wt
# ...

# %%
df.to_csv("currated_data.csv", index=False)

# %%
pd.read_csv("./currated_data.csv")
# Out:
#       resp_id  aes_canton  aes_langreg  t0sex  t0fmedu_comp  t0immig
# 0     1011011          10            2      1           1.0      3.0  \
# 1     1011013          11            1      1           1.0      1.0
# 2     1011020          15            1      1           1.0      1.0
# 3     1011021          10            1      1           1.0      1.0
# 4     1011027          10            1      2           1.0      1.0
# ...       ...         ...          ...    ...           ...      ...
# 5266  9013468          22            2      2           0.0      1.0
# 5267  9013470          13            1      1           1.0      1.0
# 5268  9013473          11            1      1           2.0      1.0
# 5269  9013481          11            1      2           1.0      1.0
# 5270  9013497          21            3      1           2.0      1.0
#
#       t1bqvalids  t2bqvalids  t3bqvalids       t1wt       t2wt       t3wt
# ...
